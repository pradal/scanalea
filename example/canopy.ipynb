# %%
# %gui qt
import pandas as pd
from openalea.deploy.shared_data import shared_data
from vpltkdisplay import *
from IPython.display import display
from openalea.plantgl.all import *
import scanalea
from scanalea import segmentation as seg
from scanalea.codecs import read, ply
import numpy as np
from openalea.core.path import path
import pandas

# %%
data = path(scanalea.__path__[0])/'..'/'..'
datadir = data/'share'/'INRIA_maize'/'processed'/'segmentation'
files =datadir.glob('*.vtk')

report = pd.read_csv(datadir/'report.txt',
            sep=' *', 
            header=None, 
            names=['Date', 'num'], 
            infer_datetime_format=True)

report =report.sort('Date')
report['num']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-064f50dc090a> in <module>()
# ----> 1 data = path(scanalea.__path__[0])/'..'/'..'
#       2 datadir = data/'share'/'INRIA_maize'/'processed'/'segmentation'
#       3 files =datadir.glob('*.vtk')
#       4
#       5 report = pd.read_csv(datadir/'report.txt',
#
# NameError: name 'path' is not defined

# %%
def fun(x):
    return [f for f in files if ('_'+str(x)+'_') in f][0]
report['filename'] = report['num'].map(fun)
report
# Out:
#           Date  num                                           filename
# 0   2013-02-20  999  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 1   2013-02-22  998  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 2   2013-02-24  997  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 3   2013-02-26  996  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 4   2013-02-28  995  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 5   2013-03-02  994  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 6   2013-03-04  993  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 7   2013-03-06  992  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 8   2013-03-07  991  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 9   2013-03-09  990  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 10  2013-03-10  989  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 11  2013-03-11  988  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 12  2013-03-12  987  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 13  2013-03-13  986  /Users/pradal/devlp/scanalea/src/scanalea/../....
# 14  2013-03-15  985  /Users/pradal/devlp/scanalea/src/scanalea/../....
#
# [15 rows x 3 columns]

# %%
scenes = [read(fn) for fn in report['filename']]
# Out:
# WARNING:traits.has_traits:DEPRECATED: traits.has_traits.wrapped_class, 'the 'implements' class advisor has been deprecated. Use the 'provides' class decorator.

# %%
def normalised(shape, translation=(0,0,0), color=(60,150,80) ):
    bc=BBoxComputer(Discretizer())
    shape.apply(bc)
    bbox = bc.boundingbox
    gi = shape.geometry
    X,Y=bbox.getXRange(), bbox.getYRange()
    scale = max(X,Y)
    gi=Scaled((1./scale,1./scale,1./scale),gi)
    return Shape(Translated(translation,gi),
                 Material(ambient=color,diffuse=1,specular=(40,40,40),emission=(0,0,0),shininess=1,transparency=0))

shapes = [normalised(scenes[xx][0], (xx/5,xx%5.,0), (xx*10,80,(xx*30)%255)) for xx in range(len(scenes))]

# %%
scene = Scene(shapes)
display(PlantGL(scene))
